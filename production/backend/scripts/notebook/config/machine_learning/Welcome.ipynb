# %% [markdown]
# # 欢迎进入 Notebook
# 您可以在这里编辑代码和文档，在编辑代码前您需阅读本文了解文件目录的作用及权限，以免使用不当造成数据丢失。

# %% [markdown]
# ## 关于文件目录

# %% [markdown]
# | 存储 | 路径 | 变量 | 权限 | 大小 | 备注 |
# |-------|-------|-------|-------|-------|-------|
# | 代码 | /lab/work | - | 可读写 | 不限制大小 | 1.在项目内挂载，归属于所在的项目<br>2.启动容器后，如果开启了SSH或<br>注入了JupyterLab，可以通过SSH工具<br>或JupyterLab上传下载 |
# | 数据集 | /lab/data1<br>/lab/data2<br>/lab/data3 | LAB_DATA1<br>LAB_DATA2<br>LAB_DATA3 | 只读 | 不限制大小 | 在创建时选择数据集，<br>创建项目时选择会挂载到容器内。 |
# | 模型 | /lab/model1<br>/lab/model2<br>/lab/model3 | LAB_MODEL1<br>LAB_MODEL2<br>LAB_MODEL3 | 只读 | 不限制大小 | 在创建时选择模型，<br>创建项目时选择会挂载到容器内。 |

# %%
# 试试这个经典示例
print ("Hello Notebook")

# %%
# 查看挂载的数据集
# !ls /lab/data1
# !ls $LAB_DATA1

# %%
# 查看挂载的模型
# !ls /lab/model1
# !ls $LAB_MODEL1

# %%
# 解压数据集
#! unzip /lab/data1/语义分割_V1.zip -d 语义分割V1
! unzip /lab/data1/数据集名.zip -d 数据集文件夹
! ls 数据集文件夹
